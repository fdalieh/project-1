# %%
from datascience import *

import pandas as pd
import numpy as np
import seaborn as sns







import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\Faezh Dalieh\\Desktop'

# %%
apps = pd.read_csv("AppleStore.csv")
apps
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
#narrowing down the columns
##sort_by_rating_top5 = apps.sort_values('user_rating_ver', ascending = False)
#apps.loc[[2,8,12], :]
#sort_by_rating_top5.head(n=10)
full = Table.read_table('AppleStore.csv')
partial = full.select(['track_name','user_rating','prime_genre'])
partial
# Out:
# track_name                                         | user_rating | prime_genre
# PAC-MAN Premium                                    | 4           | Games
# Evernote - stay organized                          | 4           | Productivity
# WeatherBug - Local Weather, Radar, Maps, Alerts    | 3.5         | Weather
# eBay: Best App to Buy, Sell, Save! Online Shopping | 4           | Shopping
# Bible                                              | 4.5         | Reference
# Shanghai Mahjong                                   | 4           | Games
# PayPal - Send and request money safely             | 4           | Finance
# Pandora - Music & Radio                            | 4           | Music
# PCalc - The Best Calculator                        | 4.5         | Utilities
# Ms. PAC-MAN                                        | 4           | Games
# ... (7187 rows omitted)

# %%
#Sorting the top 20 apps by user rating and listing the genre 
partial.sort('user_rating',descending =True).show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>track_name</th> <th>user_rating</th> <th>prime_genre</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Escape the Sweet Shop Series                    </td> <td>5          </td> <td>Games            </td>
#         </tr>
#         <tr>
#             <td>Laurie Hernandez the Human Emoji                </td> <td>5          </td> <td>Utilities        </td>
#         </tr>
#         <tr>
#             <td>Room Escape Game - Santa's Room                 </td> <td>5          </td> <td>Games            </td>
#         </tr>
#         <tr>
#             <td>CTFxCmoji                                       </td> <td>5          </td> <td>Social Networking</td>
#         </tr>
#         <tr>
#             <td>4x4 Dirt Track Trials Forest Driving Parking Sim</td> <td>5          </td> <td>Games            </td>
#         </tr>
#         <tr>
# ...

# %%
#grouping the data by genre and counting how many of the 7200 apps are of each genre.
genrelist = full.group('prime_genre').sort("count", descending = True).barh('prime_genre','count')
genrelist

# %%
#Grouping and counting how many of each rating out of 5 we have for the 7200 apps. 
full.hist('user_rating', normed = False)
# Out:
# C:\Users\Faezh Dalieh\Anaconda\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#scatterplots to compare the price and the rating of an app. This shows apps with the higher rating on average cost less. 
full.scatter('price','user_rating')
